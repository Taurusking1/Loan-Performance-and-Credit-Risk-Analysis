# %%
# IMPORT LIBRARIES

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
# LOAD DATASET

df = pd.read_csv("clean_loanset1.csv")

# %%
# INSPECT DATASET

df.head()
df.info()
df.describe()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 59 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                10000 non-null  int64
#  1   emp_title                         10000 non-null  object
#  2   emp_length                        10000 non-null  int64
#  3   state                             10000 non-null  object
#  4   homeownership                     10000 non-null  object
#  5   consolidated_annual_income        10000 non-null  int64
#  6   consolidated_debt_to_income       10000 non-null  float64
#  7   consolidated_verified_income      10000 non-null  object
#  8   delinq_2y                         10000 non-null  int64
#  9   months_since_last_delinq          10000 non-null  int64
#  10  earliest_credit_line              10000 non-null  int64
#  11  inquiries_last_12m                10000 non-null  int64
#  12  total_credit_lines                10000 non-null  int64
#  13  open_credit_lines                 10000 non-null  int64
#  14  total_credit_limit                10000 non-null  int64
#  15  total_credit_utilized             10000 non-null  int64
#  16  num_collections_last_12m          10000 non-null  int64
#  17  num_historical_failed_to_pay      10000 non-null  int64
#  18  months_since_90d_late             10000 non-null  int64
#  19  current_accounts_delinq           10000 non-null  int64
#  20  total_collection_amount_ever      10000 non-null  int64
#  21  current_installment_accounts      10000 non-null  int64
#  22  accounts_opened_24m               10000 non-null  int64
#  23  months_since_last_credit_inquiry  10000 non-null  int64
#  24  num_satisfactory_accounts         10000 non-null  int64
#  25  num_accounts_120d_past_due        10000 non-null  int64
#  26  num_accounts_30d_past_due         10000 non-null  int64
#  27  num_active_debit_accounts         10000 non-null  int64
#  28  total_debit_limit                 10000 non-null  int64
#  29  num_total_cc_accounts             10000 non-null  int64
#  30  num_open_cc_accounts              10000 non-null  int64
#  31  num_cc_carrying_balance           10000 non-null  int64
#  32  num_mort_accounts                 10000 non-null  int64
#  33  account_never_delinq_percent      10000 non-null  float64
#  34  tax_liens                         10000 non-null  int64
#  35  public_record_bankrupt            10000 non-null  int64
#  36  loan_purpose                      10000 non-null  object
#  37  application_type                  10000 non-null  object
#  38  loan_amount                       10000 non-null  int64
#  39  term                              10000 non-null  int64
#  40  interest_rate                     10000 non-null  float64
#  41  installment                       10000 non-null  float64
#  42  grade                             10000 non-null  object
#  43  sub_grade                         10000 non-null  object
#  44  issue_month                       10000 non-null  object
#  45  loan_status                       10000 non-null  object
#  46  initial_listing_status            10000 non-null  object
#  47  disbursement_method               10000 non-null  object
#  48  balance                           10000 non-null  float64
#  49  paid_total                        10000 non-null  float64
#  50  paid_principal                    10000 non-null  float64
#  51  paid_interest                     10000 non-null  float64
#  52  paid_late_fees                    10000 non-null  int64
#  53  term_group                        10000 non-null  object
#  54  grade_risk_score                  10000 non-null  int64
#  55  DelinquencyCategory               10000 non-null  object
#  56  risk_points                       10000 non-null  int64
#  57  at_risk_flag                      10000 non-null  int64
#  58  risk_status                       10000 non-null  object
# dtypes: float64(8), int64(36), object(15)
# memory usage: 4.5+ MB
# (10000, 59)

# %%
# CHECK DATA TYPES

df.dtypes
# Out:
# id                                    int64
# emp_title                            object
# emp_length                            int64
# state                                object
# homeownership                        object
# consolidated_annual_income            int64
# consolidated_debt_to_income         float64
# consolidated_verified_income         object
# delinq_2y                             int64
# months_since_last_delinq              int64
# earliest_credit_line                  int64
# inquiries_last_12m                    int64
# total_credit_lines                    int64
# open_credit_lines                     int64
# total_credit_limit                    int64
# total_credit_utilized                 int64
# num_collections_last_12m              int64
# num_historical_failed_to_pay          int64
# months_since_90d_late                 int64
# current_accounts_delinq               int64
# total_collection_amount_ever          int64
# current_installment_accounts          int64
# accounts_opened_24m                   int64
# months_since_last_credit_inquiry      int64
# num_satisfactory_accounts             int64
# num_accounts_120d_past_due            int64
# num_accounts_30d_past_due             int64
# num_active_debit_accounts             int64
# total_debit_limit                     int64
# num_total_cc_accounts                 int64
# num_open_cc_accounts                  int64
# num_cc_carrying_balance               int64
# num_mort_accounts                     int64
# account_never_delinq_percent        float64
# tax_liens                             int64
# public_record_bankrupt                int64
# loan_purpose                         object
# application_type                     object
# loan_amount                           int64
# term                                  int64
# interest_rate                       float64
# installment                         float64
# grade                                object
# sub_grade                            object
# issue_month                          object
# loan_status                          object
# initial_listing_status               object
# disbursement_method                  object
# balance                             float64
# paid_total                          float64
# paid_principal                      float64
# paid_interest                       float64
# paid_late_fees                        int64
# term_group                           object
# grade_risk_score                      int64
# DelinquencyCategory                  object
# risk_points                           int64
# at_risk_flag                          int64
# risk_status                          object
# dtype: object

# %%
# CHECK MISSING VALUES

df.isnull().sum()
# Out:
# id                                  0
# emp_title                           0
# emp_length                          0
# state                               0
# homeownership                       0
# consolidated_annual_income          0
# consolidated_debt_to_income         0
# consolidated_verified_income        0
# delinq_2y                           0
# months_since_last_delinq            0
# earliest_credit_line                0
# inquiries_last_12m                  0
# total_credit_lines                  0
# open_credit_lines                   0
# total_credit_limit                  0
# total_credit_utilized               0
# num_collections_last_12m            0
# num_historical_failed_to_pay        0
# months_since_90d_late               0
# current_accounts_delinq             0
# total_collection_amount_ever        0
# current_installment_accounts        0
# accounts_opened_24m                 0
# months_since_last_credit_inquiry    0
# num_satisfactory_accounts           0
# num_accounts_120d_past_due          0
# num_accounts_30d_past_due           0
# num_active_debit_accounts           0
# total_debit_limit                   0
# num_total_cc_accounts               0
# num_open_cc_accounts                0
# num_cc_carrying_balance             0
# num_mort_accounts                   0
# account_never_delinq_percent        0
# tax_liens                           0
# public_record_bankrupt              0
# loan_purpose                        0
# application_type                    0
# loan_amount                         0
# term                                0
# interest_rate                       0
# installment                         0
# grade                               0
# sub_grade                           0
# issue_month                         0
# loan_status                         0
# initial_listing_status              0
# disbursement_method                 0
# balance                             0
# paid_total                          0
# paid_principal                      0
# paid_interest                       0
# paid_late_fees                      0
# term_group                          0
# grade_risk_score                    0
# DelinquencyCategory                 0
# risk_points                         0
# at_risk_flag                        0
# risk_status                         0
# dtype: int64
